# %% [markdown]
# ### View results of aggregate test

# %%
import pandas as pd

# %%
#Change insert resume test id (csv name)
df = pd.read_csv('aggregate_test_results.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  tfidf_job_index  \
# 0           0             1401
# 1           1              267
# 2           2             2057
# 3           3              431
# 4           4             1473
# 5           5              949
# 6           6              509
# 7           7             1991
# 8           8               13
# 9           9             1790
#
#                               tfidf_job_descriptions  tfidf_scores  \
# 0  Job Title\n\nSoftware Applications Developer I...      0.603039
# 1  The Team\n\nThe IT Consumer group is accountab...      0.597568
# 2  Company Description\nPositioned at Publicis Gr...      0.588522
# 3  17791 DevOps Engineer II (Open)\n\nPosition Ty...      0.585314
# 4  Company Profile\nAt Morgan Stanley, we advise,...      0.583305
# 5  Company Summary\nIf you share a true passion f...      0.582045
# 6  Responsible for design, development and implem...      0.582037
# 7  Description\n\nPrimary Responsibilities\n\nDes...      0.581794
# 8  As a member of our Software Engineering Group ...      0.578276
# 9  Software Developer - Web\n2200 S. Lakeside Dri...      0.567747
#
#    keyword_matching_job_index  \
# 0                           0
# 1                        1521
# 2                        1515
# 3                        1516
# 4                        1517
# 5                        1518
# 6                        1519
# 7                        1520
# 8                        1522
# 9                        1513
#
#                    keyword_matching_job_descriptions  keyword_matching_scores  \
# 0  We are looking for hire experts flutter develo...                        5
# 1  Company Description\n\nGuestTek™ is a global l...                        5
# 2  JD for Software Engineer\nLocation-Hinjawadi P...                        5
# 3  The project duration is 15 days\nBudget - 10k\...                        5
# 4  Job Description*\nWe are looking for a PHP Dev...                        5
# 5  Greeting to All :\nWe are an IT Company Based ...                        5
# 6  Qualification\n\nEducation Specialisation Deta...                        5
# 7  Yo Corp. is a data communications and security...                        5
# 8  Roles & Responsibilities:\nWrite clean, mainta...                        5
# 9  Node JS Location: Chennai (Greams Road) Skills...                        5
#
#    encoder_job_index                           encoder_job_descriptions  \
# 0               1305  main responsibility hr administrator mainly ad...
# 1                517  resident administrator responsible administrat...
# 2               2225  qualification required qualification high scho...
# 3               2069  graduation bachelor ’ degree accredited colleg...
# 4               2041  position summary art science seeking dynamic d...
# 5               1205  project coordinator san jose/evergreen communi...
# 6               1454  office administrator global local total nation...
# 7                213  job code 403033 staff assistant iii duty & res...
# 8                335  administrative secretary position number 99383...
# 9               1394  Basic Qualifications :\n\nBachelor's degree in...
#
#   encoder_scores
# 0   [0.49065423]
# 1    [0.4840711]
# 2   [0.47433412]
# 3   [0.46638045]
# 4   [0.46185827]
# 5      [0.45047]
# 6   [0.45012635]
# 7   [0.44600058]
# 8   [0.44148213]
# 9   [0.43823946]

# %%
tfidf = df.iloc[:,1:4]
tfidf
# Out:
#    tfidf_job_index                             tfidf_job_descriptions  \
# 0             1401  Job Title\n\nSoftware Applications Developer I...
# 1              267  The Team\n\nThe IT Consumer group is accountab...
# 2             2057  Company Description\nPositioned at Publicis Gr...
# 3              431  17791 DevOps Engineer II (Open)\n\nPosition Ty...
# 4             1473  Company Profile\nAt Morgan Stanley, we advise,...
# 5              949  Company Summary\nIf you share a true passion f...
# 6              509  Responsible for design, development and implem...
# 7             1991  Description\n\nPrimary Responsibilities\n\nDes...
# 8               13  As a member of our Software Engineering Group ...
# 9             1790  Software Developer - Web\n2200 S. Lakeside Dri...
#
#    tfidf_scores
# 0      0.603039
# 1      0.597568
# 2      0.588522
# 3      0.585314
# 4      0.583305
# 5      0.582045
# 6      0.582037
# 7      0.581794
# 8      0.578276
# 9      0.567747

# %%
key_words = df.iloc[:,4:7]
key_words
# Out:
#    keyword_matching_job_index  \
# 0                           0
# 1                        1521
# 2                        1515
# 3                        1516
# 4                        1517
# 5                        1518
# 6                        1519
# 7                        1520
# 8                        1522
# 9                        1513
#
#                    keyword_matching_job_descriptions  keyword_matching_scores
# 0  We are looking for hire experts flutter develo...                        5
# 1  Company Description\n\nGuestTek™ is a global l...                        5
# 2  JD for Software Engineer\nLocation-Hinjawadi P...                        5
# 3  The project duration is 15 days\nBudget - 10k\...                        5
# 4  Job Description*\nWe are looking for a PHP Dev...                        5
# 5  Greeting to All :\nWe are an IT Company Based ...                        5
# 6  Qualification\n\nEducation Specialisation Deta...                        5
# 7  Yo Corp. is a data communications and security...                        5
# 8  Roles & Responsibilities:\nWrite clean, mainta...                        5
# 9  Node JS Location: Chennai (Greams Road) Skills...                        5

# %%
key_words.loc['keyword_matching_job_descriptions']

# %%
encoder = df.iloc[:,7:10]
encoder
# Out:
#    encoder_job_index                           encoder_job_descriptions  \
# 0               1305  main responsibility hr administrator mainly ad...
# 1                517  resident administrator responsible administrat...
# 2               2225  qualification required qualification high scho...
# 3               2069  graduation bachelor ’ degree accredited colleg...
# 4               2041  position summary art science seeking dynamic d...
# 5               1205  project coordinator san jose/evergreen communi...
# 6               1454  office administrator global local total nation...
# 7                213  job code 403033 staff assistant iii duty & res...
# 8                335  administrative secretary position number 99383...
# 9               1394  Basic Qualifications :\n\nBachelor's degree in...
#
#   encoder_scores
# 0   [0.49065423]
# 1    [0.4840711]
# 2   [0.47433412]
# 3   [0.46638045]
# 4   [0.46185827]
# 5      [0.45047]
# 6   [0.45012635]
# 7   [0.44600058]
# 8   [0.44148213]
# 9   [0.43823946]
