# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration, AutoTokenizer

# Trained Model ko load karo
model_path = "./cover_letter_model_2"
model = T5ForConditionalGeneration.from_pretrained(model_path, local_files_only=True)
# tokenizer = T5Tokenizer.from_pretrained(model_path, local_files_only=True)

# %%
tokenizer = T5Tokenizer.from_pretrained("t5-small")
# Out:
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565

# %%
import os

model_path = "./cover_letter_model_2"  # Model ka folder

print("exists:", os.path.exists(model_path))

print("contents:", os.listdir(model_path) if os.path.exists(model_path) else "NO DIR")
print(os.listdir("./cover_letter_model_2"))
# Out:
# exists: True
# contents: ['model.safetensors', 'checkpoint-612', 'tokenizer_config.json', 'config.json', 'tokenizer.json', 'generation_config.json', 'checkpoint-408']
# ['model.safetensors', 'checkpoint-612', 'tokenizer_config.json', 'config.json', 'tokenizer.json', 'generation_config.json', 'checkpoint-408']

# %%
def generate_cover_letter(job_title, qualifications, skills, experience):
    input_text = f"Job Title: {job_title}\nQualifications: {qualifications}\nSkills: {skills}\nExperience: {experience}"
    
    inputs = tokenizer(input_text, return_tensors="pt", max_length=512, truncation=True)
    
    output = model.generate(**inputs, max_length=512, do_sample=True, top_k=50, top_p=0.95)
    cover_letter = tokenizer.decode(output[0], skip_special_tokens=True)
    
    return cover_letter

# Example Test
print(generate_cover_letter(
    "Data Scientist",
    "B.Tech in Computer Science",
    "Python, Machine Learning, Deep Learning",
    "2 years as a Data Scientist at XYZ"
))
# Out:
# Good work description of the Data Scientist position at XYZ. This is a proven and qualified candidate for the Data Scientist position. With a strong background in Python, Machine Learning, and deep learning, I have been involved in this role. I look forward to the opportunity to contribute to our company. In my current position as a Data Scientist at XYZ, my skills and experience in Python, machine learning and deep learning have helped drive your team to the next level of work. Since then, I have developed a strong understanding of the field of machine learning techniques. I am confident that the aims of XYZ Interactive Computing platform. I would like to know about the importance of the ability to compete for the Data Scientist position at XYZ. I am confident in my ability to study machine learning. I am thrilled about the opportunity to contribute to XYZ.
