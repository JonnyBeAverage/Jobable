# %%
from sklearn.feature_extraction.text import CountVectorizer
from load_data import load_data
import pandas as pd
from jobable.ml_logic.data_keywords import list_of_keywords

# %%
job_df = load_data('../data/job_title_des.csv')
job_df
# Out:
#       Unnamed: 0              Job Title  \
# 0              0      Flutter Developer
# 1              1       Django Developer
# 2              2       Machine Learning
# 3              3          iOS Developer
# 4              4   Full Stack Developer
# ...          ...                    ...
# 2272        2399      Backend Developer
# 2273        2400   Full Stack Developer
# 2274        2401  Network Administrator
# 2275        2402       Machine Learning
# 2276        2403   Full Stack Developer
#
#                                         Job Description
# 0     We are looking for hire experts flutter develo...
# 1     PYTHON/DJANGO (Developer/Lead) - Job Code(PDJ ...
# 2     Data Scientist (Contractor)\n\nBangalore, IN\n...
# 3     JOB DESCRIPTION:\n\nStrong framework outside o...
# 4     job responsibility full stack engineer – react...
# ...                                                 ...
# 2272  Job Summary\nPublished on : 26 days ago\nVacan...
# 2273  business entity cisco umbrella focus cloud-bas...
# 2274  Urgently reqd in a college in Mohali\nNetwork ...
# 2275  Key Responsibilities: Team leads for small or ...
# 2276  leslie hindman auctioneer one nation 's leadin...
#
# [2277 rows x 3 columns]

# %%
vectorizer = CountVectorizer(stop_words='english', ngram_range=(1,2), min_df=5)

# %%
X = vectorizer.fit_transform(job_df['Job Description'])

# %%
X = X.toarray()

# %%
X = pd.DataFrame(X, columns=vectorizer.get_feature_names_out())

# %%
list_keys = list(list_of_keywords)
list_keys
# Out:
# ['airflow',
#  'bitbucket',
#  'google cloud composer',
#  'gcp',
#  'mysql',
#  'research scientist',
#  'dashboards',
#  'product analytics',
#  'time series forecasting',
#  'matlab',
#  'lda',
#  'hive',
#  'microsoft certified data scientist',
#  'azure synapse',
#  'nonparametric tests',
#  's3',
#  'computer vision',
#  'attention mechanisms',
#  'naive bayes',
#  'transformers',
#  'beam',
#  'boosting',
#  'word embeddings',
#  'marketing analytics',
#  'seaborn',
#  'production machine learning',
#  'outlier handling',
#  'data transformation',
#  'bandits',
#  'tokenization',
#  'word2vec',
#  'generative adversarial networks',
#  'vlookup',
#  'a/b testing',
#  'snowflake on aws',
#  'stakeholder management',
#  'tidyverse',
#  'tensorflow',
#  'model lifecycle',
#  'data factory',
#  'stop word removal',
#  'julia',
#  'azure devops',
#  'luigi',
#  'performance metrics',
#  'scipy',
#  'aws athena',
#  'inferential statistics',
#  'one-hot encoding',
#  'kibana',
#  'integration testing',
#  'apache spark',
#  'collaborative filtering',
#  'mcmc',
#  'model drift',
#  'cohort analysis',
#  'trino',
#  'forecasting',
#  'c++',
#  'churn analysis',
#  'data quality',
#  'scrum',
#  'cdc',
#  'target encoding',
#  'mle',
#  'data cleaning',
#  'spark sql',
#  'markov chain monte carlo',
#  'grafana',
#  'sentiment analysis',
#  'hortonworks',
#  'missing data imputation',
#  'leading projects',
#  'c',
#  'bagging',
#  'stochastic processes',
#  'operations analytics',
#  "bachelor's in mathematics",
#  'microsoft excel',
#  'working with product managers',
#  'bigquery',
#  'support vector machines',
#  'opencv',
#  'plotly',
#  'ad-hoc analysis',
#  'azure',
#  'business intelligence',
#  'leadership',
#  'stakeholder communication',
#  'datacamp',
#  'prefect',
#  'infrastructure as code',
#  'power bi',
#  'supervised learning',
#  'aws certified machine learning',
#  'amazon redshift',
#  'tdd',
#  'mlops',
#  'azure data lake',
#  'stemming',
#  'vertex ai',
#  'recurrent neural networks',
#  'critical thinking',
#  'cnn',
#  'mdm',
#  'dagster',
#  'customer analytics',
#  'experimentation',
#  'kpi',
#  'data.table',
#  'microservices',
#  'model registry',
#  'analytics engineer',
#  'dplyr',
#  'rest apis',
#  'explainable ai',
#  'sklearn',
#  'dbt cloud',
#  'statsmodels',
#  'feature selection',
#  'linear algebra',
#  'xgboost',
#  'qlik',
#  'ci/cd',
#  'umap',
#  'bi analyst',
#  'model explainability',
#  'business analyst',
#  'terraform',
#  'survival analysis',
#  'growth analytics',
#  'pytorch',
#  'normalization',
#  'oracle',
#  'rstudio',
#  'attention to detail',
#  'pymc4',
#  'elastic net',
#  'supply chain analytics',
#  'recommender systems',
#  'svm',
#  'github',
#  'dimensional modeling',
#  'lightgbm',
#  'clustering',
#  'sqlite',
#  'data engineer intern',
#  'talend',
#  'variational autoencoders',
#  'building apis',
#  'shiny',
#  'sql',
#  'lime',
#  'gcp dataproc',
#  'logistic regression',
#  'aws s3',
#  'change data capture',
#  'dimensionality reduction',
#  'self-starter',
#  'feature scaling',
#  'decision scientist',
#  'aws emr',
#  'db2',
#  'spark',
#  'probability',
#  "master's in statistics",
#  'knn',
#  'snowflake on gcp',
#  'speech recognition',
#  'anomaly detection',
#  'data lake',
#  'pipeline automation',
#  'clean code',
#  'redshift',
#  'sarima',
#  'data pipelines',
#  'phd',
#  'oltp',
#  'pull requests',
#  'decision trees',
#  'lstm',
#  'flink',
#  'fast learner',
#  'fivetran',
#  'monitoring',
#  'credit risk',
#  'flask',
#  'monte carlo simulation',
#  'maximum likelihood estimation',
#  'k-means',
#  'etl developer',
#  'ml orchestration',
#  'google cloud functions',
#  'cloudera',
#  'data-driven decision making',
#  'rapids',
#  'gradient boosting',
#  'tidyr',
#  'mentoring',
#  'recommendation engines',
#  'mode analytics',
#  'django',
#  'text preprocessing',
#  'optimization',
#  'batch scoring',
#  'fastapi',
#  'fairness',
#  'descriptive analytics',
#  'online scoring',
#  'redash',
#  "bachelor's degree in computer science",
#  'circleci',
#  'databricks certification',
#  'ml platforms',
#  'hdfs',
#  'kaggle',
#  'convex optimization',
#  'master data management',
#  'denormalization',
#  'mask r-cnn',
#  'tecton',
#  'large language models',
#  'project management',
#  'pivot tables',
#  'google sheets',
#  'unsupervised learning',
#  'superset',
#  'segmentation',
#  'yolo',
#  'pymc3',
#  'aws certified data analytics',
#  'software engineering',
#  'kubernetes',
#  'google professional data engineer',
#  'gcp dataflow',
#  'batch processing',
#  'data modeling',
#  'ensemble methods',
#  'snowflake on azure',
#  'sas',
#  'dask',
#  'time series analysis',
#  'data ingestion',
#  'bert',
#  'hierarchical clustering',
#  'aws lambda',
#  'vba',
#  'regex',
#  'excel dashboards',
#  'mariadb',
#  'agile',
#  'analytical mindset',
#  'senior data scientist',
#  'data science intern',
#  'feature importance',
#  'bayesian statistics',
#  'typescript',
#  'microsoft azure',
#  'working with engineers',
#  'prophet',
#  'recommendation systems',
#  'topic modeling',
#  'problem solving',
#  'azure databricks',
#  'aws glue',
#  'autoencoders',
#  'applied scientist',
#  'matplotlib',
#  'gitlab',
#  'elt',
#  'ggplot2',
#  'natural language processing',
#  'model selection',
#  'shell scripting',
#  'content-based filtering',
#  'c#',
#  'kimball',
#  'ranking',
#  'seq2seq',
#  'n-grams',
#  'machine learning engineer',
#  'hyperparameter tuning',
#  'customer segmentation',
#  'gcs',
#  'stacking',
#  'feature engineering',
#  'mapreduce',
#  'ner',
#  'dbt',
#  'rnn',
#  'data wrangling',
#  'cuml',
#  'data scientist',
#  'data warehouse',
#  'kinesis',
#  'analytics intern',
#  'var',
#  'jupyterlab',
#  'r',
#  'elk stack',
#  'ssis',
#  'xai',
#  'shadow deployment',
#  'java',
#  'data lineage',
#  'apache kafka',
#  'apache flink',
#  'aws sagemaker',
#  'looker',
#  'shap',
#  'predictive analytics',
#  'glove',
#  'hypothesis testing',
#  'dynamodb',
#  'javascript',
#  'code review',
#  'diagnostic analytics',
#  'qlikview',
#  'encoder-decoder',
#  'ml pipelines',
#  'statistician',
#  'google bigquery',
#  'model serving',
#  'index match',
#  'sequence models',
#  'clickhouse',
#  'stata',
#  'standardization',
#  'python',
#  'neural networks',
#  'design patterns',
#  'caret',
#  'postgresql',
#  'version control',
#  'exploratory data analysis',
#  'sql queries',
#  'spark streaming',
#  'data preprocessing',
#  'financial analytics',
#  'descriptive statistics',
#  'scikit-learn',
#  'star schema',
#  'informatica',
#  'prescriptive analytics',
#  'dbscan',
#  'cassandra',
#  'containers',
#  'reinforcement learning',
#  'bayesian inference',
#  'convolutional neural networks',
#  'databricks',
#  'altair',
#  'unit testing',
#  'random forests',
#  'azure ml',
#  'text classification',
#  'data governance',
#  'data integration',
#  'apache airflow',
#  'feature store',
#  'ml engineer',
#  'communication skills',
#  'sampling methods',
#  'regression',
#  'gpt',
#  'snowflake schema',
#  'streaming pipelines',
#  'mongodb',
#  'ridge regression',
#  'big data engineer',
#  'pricing analytics',
#  'bootstrapping',
#  'linux',
#  'emr',
#  'amazon web services',
#  'linear regression',
#  'regression analysis',
#  'logging',
#  'risk analytics',
#  'working with business stakeholders',
#  'model deployment',
#  'keras',
#  'redis',
#  'dbt core',
#  'confidence intervals',
#  'excel',
#  'vertica',
#  'label encoding',
#  'data normalization',
#  'regular expressions',
#  'lasso',
#  'data munging',
#  'pca',
#  'mlr',
#  'cross-functional collaboration',
#  'cross-validation',
#  'strong communication',
#  'gru',
#  'spyder',
#  'gan',
#  'mlops engineer',
#  'canary deployment',
#  'pyspark',
#  'k8s',
#  'data engineer',
#  'jupyter',
#  'kafka',
#  'data storytelling',
#  'arima',
#  'kpis',
#  'edx',
#  'reporting',
#  'test-driven development',
#  "bachelor's in statistics",
#  'k-nearest neighbors',
#  'catboost',
#  'snowflake',
#  'google data studio',
#  'cloud computing',
#  'cudf',
#  'real-time data',
#  'anova',
#  'metrics',
#  'coursera',
#  'pymc',
#  'rmarkdown',
#  'jax',
#  'pandas',
#  'unix',
#  'excel macros',
#  'storm',
#  'neo4j',
#  'nlp',
#  'named entity recognition',
#  'llms',
#  'feast',
#  'statistical modeling',
#  'serverless',
#  'metabase',
#  'command line',
#  'olap',
#  'object detection',
#  'mlflow',
#  'github actions',
#  'branching',
#  'semi-supervised learning',
#  'fbprophet',
#  'vae',
#  'self-supervised learning',
#  'data analyst',
#  'contextual bandits',
#  'elasticsearch',
#  'continuous delivery',
#  'marketing attribution',
#  'hadoop',
#  'teradata',
#  'airflow on spark',
#  'prometheus',
#  'postgres',
#  'jenkins',
#  'sql server',
#  'experimentation platform',
#  'funnel analysis',
#  'data drift',
#  'google professional machine learning engineer',
#  'experiment tracking',
#  'responsible ai',
#  'quant analyst',
#  'kubeflow',
#  'qlik sense',
#  'sparklyr',
#  'impala',
#  'kanban',
#  'feature extraction',
#  'bash',
#  'stitch',
#  'numpy',
#  'ray',
#  'scala',
#  'bokeh',
#  'etl',
#  'eda',
#  'continuous integration',
#  'outlier detection',
#  'looker studio',
#  'azure functions',
#  'ggplot',
#  "bachelor's in engineering",
#  'data lakehouse',
#  'logistics optimization',
#  "master's degree in data science",
#  'reporting automation',
#  'tableau server',
#  'pytest',
#  'udacity',
#  'docker',
#  'classification',
#  'tableau',
#  'sequence-to-sequence',
#  'presenting insights',
#  'inmon',
#  'google cloud platform',
#  'model monitoring',
#  'quantitative analyst',
#  'vs code',
#  'fraud detection',
#  "master's in computer science",
#  'unittest',
#  'probability distributions',
#  'p-values',
#  'image classification',
#  'presto',
#  'apache beam',
#  'git',
#  'google cloud storage',
#  'encoding categorical variables',
#  'aws',
#  't-sne',
#  'jupyter notebook',
#  'lemmatization',
#  'deep learning',
#  'ai engineer',
#  'tableau prep']

# %%
result = dict()

# %%
for kw in list_keys:
    if kw in X.columns:
        result[kw] = X[kw].sum()

# %%
list_count = []

# %%
list_count = result.items()
list_count
# Out:
# dict_items([('bitbucket', 61), ('gcp', 73), ('mysql', 557), ('dashboards', 23), ('matlab', 16), ('hive', 28), ('s3', 65), ('computer vision', 52), ('naive bayes', 5), ('boosting', 7), ('tensorflow', 62), ('azure devops', 33), ('performance metrics', 7), ('scipy', 9), ('kibana', 18), ('integration testing', 33), ('apache spark', 5), ('forecasting', 17), ('data quality', 25), ('scrum', 177), ('data cleaning', 6), ('grafana', 33), ('sentiment analysis', 7), ('opencv', 14), ('azure', 264), ('business intelligence', 19), ('leadership', 206), ('power bi', 8), ('tdd', 35), ('critical thinking', 18), ('cnn', 11), ('experimentation', 14), ('microservices', 133), ('rest apis', 85), ('business analyst', 7), ('terraform', 79), ('pytorch', 42), ('oracle', 237), ('recommender systems', 5), ('svm', 13), ('github', 136), ('clustering', 21), ('sqlite', 30), ('building apis', 5), ('sql', 777), ('logistic regression', 8), ('aws s3', 5), ('db2', 32), ('spark', 72), ('probability', 24), ('anomaly detection', 16), ('clean code', 35), ('redshift', 19), ('data pipelines', 14), ('phd', 28), ('oltp', 5), ('decision trees', 9), ('lstm', 10), ('fast learner', 13), ('monitoring', 396), ('flask', 63), ('mentoring', 75), ('django', 368), ('optimization', 238), ('fairness', 5), ('circleci', 7), ('hdfs', 8), ('kaggle', 6), ('project management', 67), ('unsupervised learning', 5), ('segmentation', 16), ('yolo', 5), ('software engineering', 165), ('kubernetes', 207), ('data modeling', 37), ('sas', 22), ('bert', 8), ('aws lambda', 15), ('vba', 8), ('mariadb', 6), ('agile', 665), ('typescript', 85), ('microsoft azure', 15), ('problem solving', 439), ('matplotlib', 7), ('gitlab', 46), ('shell scripting', 50), ('ranking', 13), ('feature engineering', 10), ('mapreduce', 9), ('rnn', 5), ('data scientist', 71), ('data warehouse', 18), ('kinesis', 9), ('elk stack', 14), ('ssis', 19), ('java', 989), ('predictive analytics', 7), ('dynamodb', 35), ('javascript', 1456), ('code review', 45), ('standardization', 8), ('python', 973), ('neural networks', 22), ('design patterns', 219), ('postgresql', 114), ('version control', 159), ('sql queries', 26), ('informatica', 14), ('cassandra', 51), ('containers', 61), ('reinforcement learning', 7), ('databricks', 5), ('unit testing', 128), ('data integration', 12), ('ml engineer', 5), ('communication skills', 457), ('regression', 47), ('mongodb', 229), ('linux', 425), ('emr', 15), ('logging', 42), ('keras', 30), ('redis', 81), ('excel', 85), ('strong communication', 56), ('pyspark', 6), ('k8s', 12), ('kafka', 80), ('kpis', 7), ('reporting', 174), ('snowflake', 8), ('cloud computing', 33), ('metrics', 69), ('jax', 8), ('pandas', 26), ('unix', 131), ('nlp', 70), ('serverless', 29), ('command line', 15), ('branching', 18), ('data analyst', 11), ('elasticsearch', 49), ('continuous delivery', 50), ('hadoop', 85), ('teradata', 24), ('prometheus', 26), ('postgres', 51), ('jenkins', 236), ('sql server', 187), ('kanban', 27), ('bash', 66), ('numpy', 29), ('scala', 49), ('etl', 46), ('continuous integration', 178), ('azure functions', 7), ('docker', 250), ('classification', 33), ('tableau', 26), ('git', 598), ('aws', 669), ('deep learning', 86)])

# %%
list_count = sorted(list_count, key = lambda item: item[1], reverse=True)

# %%
list_count[3:30]
# Out:
# [('sql', 777),
#  ('aws', 669),
#  ('agile', 665),
#  ('git', 598),
#  ('mysql', 557),
#  ('communication skills', 457),
#  ('problem solving', 439),
#  ('linux', 425),
#  ('monitoring', 396),
#  ('django', 368),
#  ('azure', 264),
#  ('docker', 250),
#  ('optimization', 238),
#  ('oracle', 237),
#  ('jenkins', 236),
#  ('mongodb', 229),
#  ('design patterns', 219),
#  ('kubernetes', 207),
#  ('leadership', 206),
#  ('sql server', 187),
#  ('continuous integration', 178),
#  ('scrum', 177),
#  ('reporting', 174),
#  ('software engineering', 165),
#  ('version control', 159),
#  ('github', 136),
#  ('microservices', 133)]
