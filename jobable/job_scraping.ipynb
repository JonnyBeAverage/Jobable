# %%
import requests
from bs4 import BeautifulSoup

import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
url = 'https://news.ycombinator.com/item?id=47219667'
response = requests.get(url)
html_content = response.text

# %%
soup = BeautifulSoup(html_content, 'html.parser')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <html lang="en" op="item">
#  <head>
#   <meta content="origin" name="referrer"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="news.css?LdZ2DhXXhvzcCYUPSmIA" rel="stylesheet" type="text/css"/>
#   <link href="y18.svg" rel="icon"/>
#   <link href="https://news.ycombinator.com/item?id=47219667" rel="canonical"/>
#   <title>
#    Ask HN: Who wants to be hired? (March 2026) | Hacker News
#   </title>
#  </head>
#  <body>
#   <center>
#    <table bgcolor="#f6f6ef" border="0" cellpadding="0" cellspacing="0" id="hnmain" width="85%">
#     <tr>
#      <td bgcolor="#ff6600">
#       <table border="0" cellpadding="0" cellspacing="0" style="padding:2px" width="100%">
#        <tr>
#         <td style="width:18px;padding-right:4px">
#          <a href="https://news.ycombinator.com">
#           <img height="18" src="y18.svg" style="border:1px white solid; display:block" width="18"/>
#          </a>
#         </td>
# ...

# %%
tags = soup.find_all('tr', class_='athing comtr')
tags
# Out:
# [<tr class="athing comtr" id="47243014"><td><table border="0"><tr><td class="ind" indent="0"><img height="1" src="s.gif" width="0"/></td><td class="votelinks" valign="top"><center><a href="vote?id=47243014&amp;how=up&amp;goto=item%3Fid%3D47219667" id="up_47243014"><div class="votearrow" title="upvote"></div></a></center></td><td class="default"><div style="margin-top:2px; margin-bottom:-10px;"><span class="comhead"><a class="hnuser" href="user?id=jamesc2410">jamesc2410</a> <span class="age" title="2026-03-04T04:20:51 1772598051"><a href="item?id=47243014">20 minutes ago</a></span> <span id="unv_47243014"></span><span class="navs"> | <a aria-hidden="true" class="clicky" href="#47242884">next</a> <a class="togg clicky" href="javascript:void(0)" id="47243014" n="1">[–]</a><span class="onstory"></span></span></span></div><br/>
# ...

# %%
location = tag.find_all('div', class_='commtext c00')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 location = tag.find_all('div', class_='commtext c00')
#
# File ~/.pyenv/versions/3.12.9/envs/jobable/lib/python3.12/site-packages/bs4/element.py:3203, in ResultSet.__getattr__(self, key)
#    3201 def __getattr__(self, key: str) -> None:
#    3202     """Raise a helpful exception to explain a common code fix."""
# -> 3203     raise AttributeError(
#    3204         f"""ResultSet object has no attribute "{key}". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?"""
#    3205     )
#
# AttributeError: ResultSet object has no attribute "find_all". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
for tag in tags:
    print(tag.find_all(class_="commtext c00"))
# Out:
# [<div class="commtext c00">James Coulter | UX/UI Engineer / Product Designer who codes | Devtool/Big Data focus<p>Location: EU remote / open to relocate<p>Technologies: Figma, Customer/User Research, Design Systems, Rapid Prototyping, Shipping production code HTML/CSS/JS/TS/React/Tailwind<p>Résumé/CV: <a href="https://www.jamesandrewscoulter.com" rel="nofollow">https://www.jamesandrewscoulter.com</a><p>Linkedin: <a href="https://www.linkedin.com/in/jamesandrewscoulter/" rel="nofollow">https://www.linkedin.com/in/jamesandrewscoulter/</a><p>Email: hello[at]jamesandrewscoulter.com<p>ex-Zapier, Personio AU full-stack designer &amp; product builder with 10+ years xp in technical b2b software development. Seeking Product Design/Design Engineer/UX Engineer/UX/UI Designer role with cool, mindful folks working on product-led, data-heavy, technical/dev user software</p></p></p></p></p></p></div>]
# ...

# %%
for string in location.strings:
    print(string)
# Out:
# James Coulter | UX/UI Engineer / Product Designer who codes | Devtool/Big Data focus
# Location: EU remote / open to relocate
# Technologies: Figma, Customer/User Research, Design Systems, Rapid Prototyping, Shipping production code HTML/CSS/JS/TS/React/Tailwind
# Résumé/CV:
# https://www.jamesandrewscoulter.com
# Linkedin:
# https://www.linkedin.com/in/jamesandrewscoulter/
# Email: hello[at]jamesandrewscoulter.com
# ex-Zapier, Personio AU full-stack designer & product builder with 10+ years xp in technical b2b software development. Seeking Product Design/Design Engineer/UX Engineer/UX/UI Designer role with cool, mindful folks working on product-led, data-heavy, technical/dev user software

# %%
df = {"self_description": ""}

for string in location.strings:
    chunks = string.split(' ')
    values = " ".join(chunks[1:])
    print(chunks)
    if chunks[0] == "Location:":
        df['Location'] = values
    elif chunks[0] == "Remote:":
        df['Remote'] = values
    elif chunks[0] == "Willing:":
        df['Relocate_Ok'] = values
    elif chunks[0] == "Technologies:":
        df['Technologies'] = values
    elif chunks[0] in ["Resume:", "Résumé/CV:"]:
        pass
    elif chunks[0] == "Website:":
        pass
    elif chunks[0] == "Github:":
        pass
    elif chunks[0] == "Email:":
        pass
    elif chunks[0].endswith(":"):
        pass
    else:
        df['self_description'] += string + '\n' + " "
# Out:
# ['James', 'Coulter', '|', 'UX/UI', 'Engineer', '/', 'Product', 'Designer', 'who', 'codes', '|', 'Devtool/Big', 'Data', 'focus']
# ['Location:', 'EU', 'remote', '/', 'open', 'to', 'relocate']
# ['Technologies:', 'Figma,', 'Customer/User', 'Research,', 'Design', 'Systems,', 'Rapid', 'Prototyping,', 'Shipping', 'production', 'code', 'HTML/CSS/JS/TS/React/Tailwind']
# ['Résumé/CV:', '']
# ['https://www.jamesandrewscoulter.com']
# ['Linkedin:', '']
# ['https://www.linkedin.com/in/jamesandrewscoulter/']
# ['Email:', 'hello[at]jamesandrewscoulter.com']
# ['ex-Zapier,', 'Personio', 'AU', 'full-stack', 'designer', '&', 'product', 'builder', 'with', '10+', 'years', 'xp', 'in', 'technical', 'b2b', 'software', 'development.', 'Seeking', 'Product', 'Design/Design', 'Engineer/UX', 'Engineer/UX/UI', 'Designer', 'role', 'with', 'cool,', 'mindful', 'folks', 'working', 'on', 'product-led,', 'data-heavy,', 'technical/dev', 'user', 'software']

# %%
df
# Out:
# {'self_description': 'James Coulter | UX/UI Engineer / Product Designer who codes | Devtool/Big Data focus\n https://www.jamesandrewscoulter.com\n https://www.linkedin.com/in/jamesandrewscoulter/\n ex-Zapier, Personio AU full-stack designer & product builder with 10+ years xp in technical b2b software development. Seeking Product Design/Design Engineer/UX Engineer/UX/UI Designer role with cool, mindful folks working on product-led, data-heavy, technical/dev user software\n ',
#  'Location': 'EU remote / open to relocate',
#  'Technologies': 'Figma, Customer/User Research, Design Systems, Rapid Prototyping, Shipping production code HTML/CSS/JS/TS/React/Tailwind'}

# %%
# Out:
# <generator object Tag._all_strings at 0x11c82ef40>
# <generator object Tag._all_strings at 0x11c82ef40>
# <generator object Tag._all_strings at 0x11c82ef40>
# <generator object Tag._all_strings at 0x11c82ef40>
# <generator object Tag._all_strings at 0x11c82ef40>
# <generator object Tag._all_strings at 0x11c82ef40>
# <generator object Tag._all_strings at 0x11c82ef40>
# <generator object Tag._all_strings at 0x11c82ef40>
# <generator object Tag._all_strings at 0x11c82ef40>
# <generator object Tag._all_strings at 0x11c82ef40>
# <generator object Tag._all_strings at 0x11c82ef40>
